# %% [markdown]
# ### Linear Regression

# %%
import tensorflow as tf

# %%
# input Data
x_data = [[1,1],[2,2],[3,3]]
y_data = [[1],[2],[3]]

# %%
# placeholder
X = tf.placeholder(tf.float32, shape=[None, 2]) 
    # shape = [None, 2]  데이터가 몇개 들어올지 알수 없고, 변동이 계속 발생하므로 none, 한번에 2개씩 들어오므로 2
Y = tf.placeholder(tf.float32, shape=[None, 1])
    # shape = [None, 1]  데이터가 몇개 들어올지 알수 없고, 변동이 계속 발생하므로 none, 한번에 1개씩 들어오므로 1

# %%
# variable ( 변수 선언 및 임의의 값으로 초기화 )
W = tf.Variable(tf.random_normal(shape = [2])) # weight
b = tf.Variable(tf.random_normal(shape = [1])) # bias
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# model
model = X * W + b

# %%
# cost
cost =  tf.reduce_sum(tf.square(model - Y))

# %%
# train
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# %%
# Session
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Training
    for step in range(2001):
        c, w_, b_, _ = sess.run([cost, W, b, train], feed_dict = {X:x_data, Y:y_data})
        print("step:%g, c:%g, w:%s, b:%g"%(step,c,w_,b_))
        
    # Testing
    print(sess.run(model, feed_dict= {X:[[4,4]]}))
# Out:
# step:0, c:47.5931, w:[-0.7705905  -0.03803639], b:1.55707
# step:1, c:21.0432, w:[-0.46167374  0.06576521], b:1.70726
# step:2, c:10.5332, w:[-0.2572761   0.12247996], b:1.7899
# step:3, c:6.28059, w:[-0.12002634  0.15339802], b:1.83128
# step:4, c:4.50086, w:[-0.02617307  0.17069246], b:1.84753
# step:5, c:3.71448, w:[0.03945231 0.1811955 ], b:1.84848
# step:6, c:3.3354, w:[0.08658804 0.18864313], b:1.84018
# step:7, c:3.12766, w:[0.12152121 0.19500087], b:1.82633
# step:8, c:2.99434, w:[0.1483351  0.20124045], b:1.80919
# step:9, c:2.89474, w:[0.16969822 0.20779008], b:1.79014
# step:10, c:2.8113, w:[0.18736592 0.21479207], b:1.77002
# step:11, c:2.73625, w:[0.20250052 0.22224735], b:1.74936
# step:12, c:2.66604, w:[0.21587686 0.23009458], b:1.72847
# step:13, c:2.599, w:[0.22801502 0.23825178], b:1.70754
# step:14, c:2.53432, w:[0.23926644 0.2466369 ], b:1.68668
# step:15, c:2.47158, w:[0.24987023 0.25517696], b:1.66597
# step:16, c:2.41056, w:[0.25999016 0.26381102], b:1.64545
# ...
